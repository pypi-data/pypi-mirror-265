# %% [markdown]
# # Metasurfaces Data Base Genetation Ansys HFSS Interface
#
# ## _Versión 0.1_
# ### Author: Jorge Cárdenas
# ### Pontificia Universidad de Valparaíso
# This development is intended to provide an interface to access HFSS, in order to automate simulation and optimization processes.
#
# ## Features
#
# - Automate the re-creation of models in aedt files.
# - Create intermediate files to run simulations.
# - Run simulations and gather specific metrics from the simualtor.

# %%
# !pip install druida --upgrade
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: druida in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (0.0.19)
# Collecting druida
#   Downloading druida-0.0.20-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: ezdxf in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (1.1.0)
# Requirement already satisfied: imutils in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (0.5.4)
# Requirement already satisfied: matplotlib in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (3.8.2)
# Requirement already satisfied: numpy<=1.24.3 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (1.24.3)
# Collecting opencv-python (from druida)
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pandas~=2.1.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (2.1.4)
# Requirement already satisfied: pillow in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (10.1.0)
# Requirement already satisfied: scikit-learn in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (1.3.2)
# Requirement already satisfied: tensorflow==2.13.* in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (2.13.1)
# Requirement already satisfied: torchsummary in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (1.5.1)
# Requirement already satisfied: torchvision in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (0.15.2)
# Requirement already satisfied: torch~=2.0.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (2.0.1)
# Requirement already satisfied: tqdm in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (4.66.1)
# Requirement already satisfied: transformers in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from druida) (4.36.2)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from druida) (0.41.2)
# Requirement already satisfied: tensorflow-intel==2.13.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow==2.13.*->druida) (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (3.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (4.25.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.60.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from pandas~=2.1.0->druida) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from pandas~=2.1.0->druida) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from pandas~=2.1.0->druida) (2023.3)
# Requirement already satisfied: filelock in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from torch~=2.0.1->druida) (3.13.1)
# Requirement already satisfied: sympy in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from torch~=2.0.1->druida) (1.12)
# Requirement already satisfied: networkx in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from torch~=2.0.1->druida) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from torch~=2.0.1->druida) (3.1.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from ezdxf->druida) (3.1.1)
# Requirement already satisfied: fonttools in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from ezdxf->druida) (4.47.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from matplotlib->druida) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from matplotlib->druida) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from matplotlib->druida) (1.4.5)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from scikit-learn->druida) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from scikit-learn->druida) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from scikit-learn->druida) (3.2.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from torchvision->druida) (2.31.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from tqdm->druida) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from transformers->druida) (0.20.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from transformers->druida) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from transformers->druida) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from transformers->druida) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from transformers->druida) (0.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers->druida) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from jinja2->torch~=2.0.1->druida) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from requests->torchvision->druida) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from requests->torchvision->druida) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from requests->torchvision->druida) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from requests->torchvision->druida) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from sympy->torch~=2.0.1->druida) (1.3.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.*->druida) (3.2.2)
# Downloading druida-0.0.20-py3-none-any.whl (26 kB)
# Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.1 MB 10.2 MB/s eta 0:00:04
#     --------------------------------------- 0.8/38.1 MB 10.6 MB/s eta 0:00:04
#    - -------------------------------------- 1.4/38.1 MB 10.9 MB/s eta 0:00:04
#    -- ------------------------------------- 1.9/38.1 MB 10.2 MB/s eta 0:00:04
#    -- ------------------------------------- 2.5/38.1 MB 11.3 MB/s eta 0:00:04
#    --- ------------------------------------ 3.0/38.1 MB 10.8 MB/s eta 0:00:04
#    --- ------------------------------------ 3.5/38.1 MB 10.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.0/38.1 MB 10.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.6/38.1 MB 10.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.1/38.1 MB 11.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.7/38.1 MB 11.3 MB/s eta 0:00:03
#    ------ --------------------------------- 6.2/38.1 MB 11.3 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/38.1 MB 11.1 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.1 MB 11.2 MB/s eta 0:00:03
#    -------- ------------------------------- 7.9/38.1 MB 11.2 MB/s eta 0:00:03
#    -------- ------------------------------- 8.4/38.1 MB 11.5 MB/s eta 0:00:03
#    --------- ------------------------------ 9.0/38.1 MB 11.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.6/38.1 MB 11.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.1/38.1 MB 11.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 10.7/38.1 MB 11.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.2/38.1 MB 11.7 MB/s eta 0:00:03
#    ------------ --------------------------- 11.8/38.1 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.1 MB 11.7 MB/s eta 0:00:03
#    ------------- -------------------------- 12.9/38.1 MB 11.7 MB/s eta 0:00:03
#    -------------- ------------------------- 13.4/38.1 MB 11.9 MB/s eta 0:00:03
#    -------------- ------------------------- 13.6/38.1 MB 11.5 MB/s eta 0:00:03
#    -------------- ------------------------- 14.2/38.1 MB 11.3 MB/s eta 0:00:03
#    --------------- ------------------------ 14.8/38.1 MB 11.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.3/38.1 MB 11.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.9/38.1 MB 11.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.4/38.1 MB 11.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.9/38.1 MB 11.5 MB/s eta 0:00:02
#    ------------------ --------------------- 17.5/38.1 MB 11.5 MB/s eta 0:00:02
#    ------------------ --------------------- 18.0/38.1 MB 11.5 MB/s eta 0:00:02
#    ------------------- -------------------- 18.6/38.1 MB 11.5 MB/s eta 0:00:02
#    ------------------- -------------------- 18.8/38.1 MB 11.1 MB/s eta 0:00:02
#    -------------------- ------------------- 19.4/38.1 MB 11.1 MB/s eta 0:00:02
#    -------------------- ------------------- 19.9/38.1 MB 11.1 MB/s eta 0:00:02
#    --------------------- ------------------ 20.5/38.1 MB 11.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.0/38.1 MB 11.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.6/38.1 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.1/38.1 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.5/38.1 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 23.1/38.1 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 23.6/38.1 MB 10.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.2/38.1 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 24.8/38.1 MB 11.1 MB/s eta 0:00:02
#    -------------------------- ------------- 25.2/38.1 MB 11.3 MB/s eta 0:00:02
#    --------------------------- ------------ 25.8/38.1 MB 11.1 MB/s eta 0:00:02
#    --------------------------- ------------ 26.3/38.1 MB 11.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.9/38.1 MB 11.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.4/38.1 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 27.7/38.1 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.3/38.1 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 28.9/38.1 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.1 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 30.0/38.1 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 30.6/38.1 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 31.1/38.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 31.5/38.1 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.1/38.1 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.7/38.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.2/38.1 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.8/38.1 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 34.3/38.1 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 34.5/38.1 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.1 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 35.7/38.1 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 36.3/38.1 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 36.8/38.1 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  37.4/38.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  37.6/38.1 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: opencv-python, druida
#   Attempting uninstall: druida
#     Found existing installation: druida 0.0.19
#     Uninstalling druida-0.0.19:
#       Successfully uninstalled druida-0.0.19
# Successfully installed druida-0.0.20 opencv-python-4.8.1.78
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pucv.cl\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\jupyterlab\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""When working in Dev mode"""
import sys  
sys.path.insert(0, './src/')


"""when working in Production mode"""
#%pip install druidaHFSS
# Out:
# 'when working in Production mode'

# %%
import os
import uuid 
from datetime import datetime


from __future__ import print_function
#from Utilities.SaveAnimation import Video
from druidaHFSS import Manager as MG

# %% [markdown]
# ## Setup
# <p>In this section we prepare all variables to set the origin and destination folders for our resulting files</p>

# %%
ansysPath="C:\\Program Files\\AnsysEM\\AnsysEM21.2\\Win64\\ansysedt.exe"
modelName="cross_01_freq_reflect"
modelPath=r"C:/Users/jorge/Documents/Projects Jorge C/DRUIDA PROJECT/POC/dbGeneration_v0/Models/testing-multioutput/"
exportPath= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Exports"
dBPath= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\DBfiles\\"
project_name="meta-atom_cross_01_datageneration"
designName="HFSSDesign1"

#set simulation variables
#This is run to create iterative simulations

# %%
#Model builder

#ansysPath,modelName, modelPath,exportPath

Builder=MG.Builder(ansysPath=ansysPath,modelName=modelName,projectName=project_name, designName=designName,modelPath=modelPath, exportPath=exportPath)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 #Model builder
#       2
#       3 #ansysPath,modelName, modelPath,exportPath
# ----> 5 Builder=MG.Builder(ansysPath=ansysPath,modelName=modelName,projectName=project_name, designName=designName,modelPath=modelPath, exportPath=exportPath)
#
# TypeError: Builder.__init__() missing 2 required positional arguments: 'scriptPath' and 'imagesPath'

# %%
#ReCreate a aedt model from script 
#We are supposed to have previously worked our model out and keep a python script 
#to be used as source to create the geometry when required.

Builder.create()

# %% [markdown]
# # 1. A full batch of simulation for box-shaped cells
#
# ![alternatvie text](./resources/Picture1.png)

# %%
#Generate batch of vectors to simulate
import random

def parameters_Generator(constraints, batch_size, vector_size):
    x = [[0 for i in range(vector_size)] for j in range(batch_size)]

    for vector in x:
        for i, (k, v) in enumerate(constraints.items()):
            vector[i]=random.uniform(constraints[k]["max"], constraints[k]["min"])
            
    return x

# %%
batch=0
iteration=0
simfile_path= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\"
simfileName= "intermediateFile.py"

#set reports
reports={
    "ReflectanceTE":"(mag(S(FloquetPort1:1,FloquetPort1:1)))^2",
    "ReflectanceTM":"(mag(S(FloquetPort1:2,FloquetPort1:2)))^2"
    }

constraints = {"xize":{"max":4, "min":0.3,"nominaSl":1},
            "ySize":{"max":4, "min":0.3,"nominal":1},
            "zSize":{"max":0.08, "min":0.6,"nominal":0.5},
            "zSustrato":{"max":1.5, "min":0.5,"nominal":1}}

parameters = parameters_Generator(constraints, batch_size=3, vector_size=4)     



for parameter in parameters:
    
    
    #parameters, batch, iteration, filePath, **kwargs
    #Kwargs
    #AnsoftPath=kwargs['ansoft_path']
    #modelPath=kwargs['model_path'] 
    #outputPath=kwargs['output_path']
    #projectName=kwargs['project_name']
    #simulationID=kwargs['simulation_id']
    #variableName=kwargs['variable_name']
    #value=kwargs['value']
    #units=kwargs['units']
    #design=kwargs['design_name']

    #Create the intermediate simulation fiel
    
    simulation_id=str(uuid.uuid1())

    #set variables to modify
    variable_name='parameters'
    value=str(parameter)

    units="mm"
    
    kwargs={
        "reports":reports,
        "simulation_id":simulation_id,
       "variable_name":variable_name,
        "value" : value,
        "units" : units,
       }
    
    Builder.sim_file('', batch, iteration, simfile_path, **kwargs)
    
    Builder.simulate(simfile_path+simfileName)
    
    iteration+=iteration
# Out:
# "C:/Users/jorge/Documents/Projects Jorge C/DRUIDA PROJECT/POC/dbGeneration_v0/Models/testing-multioutput/meta-atom_box_01_datageneration.aedt"
# The new directory is created!
# "C:/Users/jorge/Documents/Projects Jorge C/DRUIDA PROJECT/POC/dbGeneration_v0/Models/testing-multioutput/meta-atom_box_01_datageneration.aedt"
# The new directory is created!
# "C:/Users/jorge/Documents/Projects Jorge C/DRUIDA PROJECT/POC/dbGeneration_v0/Models/testing-multioutput/meta-atom_box_01_datageneration.aedt"
# The new directory is created!

# %% [markdown]
# ## Setting a dataframe to build our DB

# %%
now=datetime.now()
dbName=modelName+' batch'+'01'+" "+str(now)[:10]+'.csv'

dbManager=MG.DBManager(ansysPath=ansysPath,
                       modelName=modelName,
                       projectName=project_name,
                       designName=designName,
                       modelPath=modelPath, 
                       dbPath=dBPath,
                      dbName=dbName)

# %%
columnNames={ "sim_id":"object",
               "created_at":"datetime64[s]",
               "iteration":'int64',
               "modelName":'object',
                 "model":'object',
               "designName":'object',
               "type":'object',
               "layers":'object',
               "params":'object',
               "paramValues":'object',
               "fMin(GHz)":'float64',
               "fMax(GHz":'float64',
               "metric":'object', 
               "freq":'float64',
               "value":'float64'}


dbManager.load_df(columns=columnNames)


"""This object can be treated as a pandas dataframe"""
dbManager.df
# Out:
# Empty DataFrame
# Columns: [sim_id, created_at, iteration, modelName, designName, type, layers, params, paramValues, fMin(GHz), fMax(GHz, metric, freq, value]
# Index: []

# %% [markdown]
# ## A sample of data structure to log in our DB

# %%
#create structs and data to store
layers= {
         "layer1":{
             "thickness":0.1,
             "material":"copper"
         },
         "layer2":{
             "thickness":0.8,
             "material":"dielectric1"
         } ,
         "layer2":{
             "thickness":0.1,
             "material":"copper"
         }
    }

params=['radius']
values=[0.3]


"""For trial. The real case needs to loop over the entire data from HFSS to load ech frequency point"""

data_to_store= {"sim_id":"simid123456",
            "created_at":"'1970-01-01T00:00:00Z'",
                "iteration":'0',
             "modelName":"meta-atom_box_01_datageneration",
            "model":"box",
             "designName":'HFSSDesign1',
             "type":'Reflective',
             "layers":layers,
             "params":params,
             "paramValues":values,
             "fMin(GHz)":5,
             "fMax(GHz)":10,
             "metric":"ReflectanceTE", 
             "freq":8.15,
            "value":0.556}

# %%
dbManager.insert_row(data_to_store)

# %% [markdown]
# # 2. A full batch of simulation with data storage

# %%
#import sys  
#sys.path.insert(0, './src/')

import os
import uuid 
from datetime import datetime


from __future__ import print_function
from druidaHFSS import Manager as MG
from druidaHFSS.modules import tools

from glob import glob
import matplotlib.pyplot as plt
import re


ansysPath="C:\\Program Files\\AnsysEM\\AnsysEM21.2\\Win64\\ansysedt.exe"
modelName="cross_01_freq_reflect"
scriptPath=r"C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\scripts\\"


r"C:/Users/jorge/Documents/Projects Jorge C/DRUIDA PROJECT/POC/dbGeneration_v0/Models/testing-multioutput/"
modelPath=r"C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\"
exportPath= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Exports"
dBPath= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\DBfiles\\"
imagesPath="C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Images"

#simulating box shaped meta atom
project_name="meta-atom_cross_01_datageneration"
designName="HFSSDesign1"
modeltype="Reflective"

#set simulation variables
#This is run to create iterative simulations
Builder=MG.Builder(ansysPath=ansysPath,
                   modelName=modelName,
                   projectName=project_name, 
                   designName=designName,
                   modelPath=modelPath,
                   scriptPath=scriptPath,
                   exportPath=exportPath,
                   imagesPath=imagesPath)
# Out:
# The new Exports directory is created!
# The new Images directory is created!

# %%
"""If creating a model is required then:"""
Builder.create()

# %%
#Generate batch of vectors to simulate
"""This function must be custom made"""
import random
#[width, length, cond z, subs z, subs LxL]
def parameters_Generator(constraints, batch_size, vector_size):
    x = [[0 for i in range(vector_size)] for j in range(batch_size)]

    for vector in x:
        for i, (k, v) in enumerate(constraints.items()):
            if k!='zSustrato':
                vector[i]=random.uniform(constraints[k]["max"], constraints[k]["min"])
            else:
                 vector[i] = random.choice([1.575, 0.787, 0.508, 0.252 ])
             
    return x

# %%
#Simulation setting
batch=0
batch_size=1000
batches=1
iteration=0
simfile_path= "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\"
simfileName= "intermediateFileCross.py"

#set reports
reports={
    "ReflectanceTE":"(mag(S(FloquetPort1:1,FloquetPort1:1)))^2",
    "ReflectanceTM":"(mag(S(FloquetPort1:2,FloquetPort1:2)))^2",
    "TransmittanceTE":"(mag(S(FloquetPort2:1,FloquetPort2:1)))^2",
    "TransmittanceTM":"(mag(S(FloquetPort2:2,FloquetPort2:2)))^2",
    "AbsorbanceTE":"1-((mag(S(FloquetPort1:1,FloquetPort1:1)))^2 +(mag(S(FloquetPort2:1,FloquetPort1:1)))^2)",
    "AbsorbanceTM":"1-((mag(S(FloquetPort1:2,FloquetPort1:2)))^2 +(mag(S(FloquetPort2:2,FloquetPort1:2)))^2)"
    }

#Rogers standars
#metalization 0.07mm, 0.035mm
#dielectric 1.575mm, 0.787 mm, 0.508mm, 0.252mm


constraints = {"arm_w":{"max":3.0, "min":0.1,"nominal":1},
            "arm_l":{"max":4.5, "min":2.0,"nominal":1},
            "zSize":{"max":0.035, "min":0.035,"nominal":0.5},
            "zSustrato":{"max":1.575, "min":0.252,"nominal":1},
            "Sustrato":{"max":5.3, "min":4.9,"nominal":5}}

"""name in the hfss design"""
variable_name='parameters'

parameters = parameters_Generator(constraints, batch_size=batch_size, vector_size=len(list(constraints.keys()) ))
parameters_names=list(constraints.keys())

#Data setting

now=datetime.now()
dbName=modelName+' batch'+str(batch)+" "+str(now)[:10]+'.csv'

dbManager=MG.DBManager(ansysPath=ansysPath,
                       modelName=modelName,
                       projectName=project_name,
                       designName=designName,
                       modelPath=modelPath, 
                       dbPath=dBPath,
                      dbName=dbName)

# %%
columnNames={ "sim_id":"object",
               "created_at":"datetime64[s]",
               "iteration":'int64',
               "projectName":'object',
                 "modelName":'object',
               "designName":'object',
               "type":'object',
               "layers":'object',
               "params":'object',
               "paramValues":'object',
             "units":'object',
               "fMin(GHz)":'float64',
               "fMax(GHz":'float64',
               "metric":'object', 
               "freq":'float64',
               "value":'float64'}


dbManager.load_df(columns=columnNames)


"""This object can be treated as a pandas dataframe"""
dbManager.df
# Out:
# Empty DataFrame
# Columns: [sim_id, created_at, iteration, projectName, modelName, designName, type, layers, params, paramValues, units, fMin(GHz), fMax(GHz, metric, freq, value]
# Index: []

# %%
simulation_id=str(uuid.uuid1())

for parameter in parameters:
    
    #Describe the layers used in your model
    #create structs and data to store
    layers= {
             "conductor":{
                 "thickness":parameter[2],
                 "material":"copper"
             },
             "conductor2":{
                 "thickness":0,
                 "material":"pec"
             } ,
             "substrate":{
                 "thickness":parameter[3],
                 "material":"Rogers RT/duroid 5880 (tm)"
             }
        }
    
    #parameters, batch, iteration, filePath, **kwargs
    #Kwargs
    #AnsoftPath=kwargs['ansoft_path']
    #modelPath=kwargs['model_path'] 
    #outputPath=kwargs['output_path']
    #projectName=kwargs['project_name']
    #simulationID=kwargs['simulation_id']
    #variableName=kwargs['variable_name']
    #value=kwargs['value']
    #units=kwargs['units']
    #design=kwargs['design_name']

    #Create the intermediate simulation fiel
    
    

    #set variables to modify
    value=str(parameter)

    units="mm"
    
    kwargs={
        "reports":reports,
        "simulation_id":simulation_id,
       "variable_name":variable_name,
        "value" : value,
        "units" : units,
        "sim_file_name" : simfileName
       }
    
    Builder.sim_file('', batch, iteration, simfile_path, **kwargs)
    
    Builder.simulate(simfile_path+simfileName)
    

    """For trial. The real case needs to loop over the entire data from HFSS to load ech frequency point"""

    data_to_store= {"sim_id":str(simulation_id),
                "created_at":str(now)[:10],
                    "iteration":str(iteration),
                 "projectName":project_name,
                "modelName":modelName,
                 "designName":designName,
                 "type":modeltype,
                 "layers":layers,
                 "params":str(parameters_names),
                 "paramValues":str(value),
                    "units":str(units),
                 "fMin(GHz)":30,
                 "fMax(GHz)":90,
                 "metric":str(reports), 
                 "freq":'',
                "value":''}
    
    dbManager.insert_row(data_to_store)
    
    iteration=iteration+1
# Out:
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# The new directory is created!
# The new directory is created!
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"
# "C:\\Users\\jorge\\Documents\\Projects Jorge C\\DRUIDA PROJECT\\POC\\dbGeneration_v0\\Models\\testing-multioutput\\meta-atom_cross_01_datageneration.aedt"

# %% [markdown]
# ## Post processing images

# %%
folders=glob(imagesPath+"/*/", recursive = True)
files=[]

for folder in folders:
    if folder != imagesPath+"\\"+ "processed\\":
        files=(files+glob(folder+"/*"))

# %%
for file in files:
    fileName_absolute = os.path.basename(file) 
    path=os.path.dirname(file)

    #ROI is 
    image_rgb=tools.cropImage( file,image_path=path,
                              image_name=fileName_absolute,
                              output_path=imagesPath, 
                             resize_dim=(512,512))
# Out:
# The new directory is created!
